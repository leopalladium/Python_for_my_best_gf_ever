# %% [markdown]
# # Решение задач по программированию
# Дорогая Аня, пишу тебе это всё в *Jupyter*, чтобы заодно познакомить тебя немножко лучше с тем, как мы будем решать задачи во время разработки твоего проекта (прости, я забыл что за предмет).
# ## Jupyter
# Так вот, Jupyter, если вкратце это штука, которая позволяет миксовать текстовую разметку, куски кода, картинки и всё остальное в один файл, чтобы нам удобно с ним было работать, сразу видеть выводы функций и всё такое, а ещё много другого, думаю так или иначе у нас классная возможность познакомиться с таким важным инструментом поближе.
#
# ## Как пользоваться Jupyter
# Я немного ошибся в тот момент, когда думал, что Jupyter требует какой-то мега сложной настройки (такое бывает и это истинно для языков кроме Python), но вот этот *Notebook* я пишу сейчас в PyCharm, так что да.
# Весь Notebook состоит из *Cells* или *клеток/ячеек*, которые могут быть двух типов:
# * Ячейка с кодом
# * Ячейка с текстом (как например эта)
#
# Переход от одной к следующей возможен с помощью *Shift + Enter*.
#
# ## Как писать код?
# Признаться честно, каждая ячейка в твоём *Notebook* является кусочком файла и можно просто менять и сразу видеть вывод, а ещё можно сделать например вот так

# %%
# Нажми Shift + Enter
myString = "Я люблю тебя"

# %% [markdown]
# И оно сохранит переменную, но что вдруг, если мы захоти узнать, что в неё действительно записалось? Неужели придётся постоянно дрочить бесконечные
# ```python
# print(myString)
# ```
# Слава богу, ответ — нет!

# %%
# Ведь можно просто написать в ячейке имя переменной и оно Jupyter выведет нам это в поле Out под ячейку
myString

# %% [markdown]
# Сверху кстати появилась эта штука, поле вывода, про которое я писал. Надеюсь более-менее объяснил главные фишки. Люблю тебя и увидимся в следующем *Notebook*, где уже будем пошагово разбирать решение твоих задач!
